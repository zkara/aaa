# %%
import pandas
import os
import tarfile
import urllib.request
import numpy as np
import plot
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"
def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    os.makedirs(housing_path, exist_ok=True)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-81-00707ba2a8e6> in <module>()
#       4 import urllib.request
#       5 import numpy as np
# ----> 6 import plot
#       7 DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
#       8 HOUSING_PATH = os.path.join("datasets", "housing")
#
# ModuleNotFoundError: No module named 'plot'

# %%
data_set = pandas.read_csv("datasets/housing/housing.csv")
data_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# ...

# %%
data_set["median_income"].describe()


# On remarque qu'il y'a moins de chiffres non-null dans les total-bedroom.
# Out:
# count    20640.000000
# mean         3.870671
# std          1.899822
# min          0.499900
# 25%          2.563400
# 50%          3.534800
# 75%          4.743250
# max         15.000100
# Name: median_income, dtype: float64

# %%
data_set.hist(figsize = (20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f204d902940>,
# ...
#       dtype=object)

# %%
data_set["room/population"] = data_set["total_rooms"]/ data_set["population"]

data_set["bedroom/room"] = data_set["total_bedrooms"]/ data_set["total_rooms"]
data_set["income/pop"] = data_set["median_income"]/ data_set["housing_median_age"]
data_set["households/room"] = data_set["households"]/ data_set["total_rooms"]

# %%
d=data_set.corr(method=histogram_intersection)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-95f90bc07133> in <module>()
# ----> 1 d=data_set.corr(method=histogram_intersection)
#
# NameError: name 'histogram_intersection' is not defined

# %%
d
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
# Population/Room      0.005178 -0.004598            0.023236    -0.032869
# room/population     -0.074420  0.140345           -0.107926     0.129274
# bedroom/room         0.092657 -0.113815            0.136089    -0.187900
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
data = data_set.copy()
# Out:
# OrdinalEncoder(categories='auto', dtype=<class 'numpy.float64'>)

# %%
enc = OrdinalEncoder()
G = data["ocean_proximity"].values.reshape(-1,1)
enc.fit(G)
# Out:
# OrdinalEncoder(categories='auto', dtype=<class 'numpy.float64'>)

# %%
data["newOcean_proximity"] = enc.transform(G)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# ...

# %%
data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
# Population/Room      0.005178 -0.004598            0.023236    -0.032869
# room/population     -0.074420  0.140345           -0.107926     0.129274
# bedroom/room         0.092657 -0.113815            0.136089    -0.187900
# ...

# %%
np.log(data["housing_median_age"])
# Out:
# 0        3.713572
# 1        3.044522
# 2        3.951244
# 3        3.951244
# 4        3.951244
# 5        3.951244
# 6        3.951244
# 7        3.951244
# 8        3.737670
# 9        3.951244
# 10       3.951244
# 11       3.951244
# 12       3.951244
# 13       3.951244
# 14       3.951244
# 15       3.912023
# 16       3.951244
# 17       3.951244
# 18       3.912023
# 19       3.951244
# 20       3.688879
# 21       3.737670
# 22       3.951244
# 23       3.951244
# 24       3.951244
# 25       3.713572
# 26       3.891820
# 27       3.951244
# 28       3.912023
# 29       3.951244
#            ...
# 20610    3.332205
# 20611    3.295837
# 20612    3.258097
# 20613    3.433987
# 20614    3.258097
# 20615    3.135494
# 20616    2.708050
# 20617    2.995732
# 20618    3.218876
# 20619    3.091042
# 20620    3.688879
# 20621    3.610918
# 20622    2.995732
# 20623    3.465736
# 20624    2.772589
# 20625    3.610918
# 20626    3.583519
# 20627    1.609438
# 20628    2.944439
# ...

# %%
import seaborn as sns
copytrain = data.corr()
sns.heatmap(copytrain, annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-f8fc4d0e0603> in <module>()
#       2 copytrain = data.corr()
#       3 sns.heatmap(copytrain, annot=True)
# ----> 4 plt.show()
#
# NameError: name 'plt' is not defined
